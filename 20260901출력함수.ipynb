# %% [markdown]
# <a href="https://colab.research.google.com/github/26432-ops/10812/blob/main/20260901%EC%B6%9C%EB%A0%A5%ED%95%A8%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=input('이름:')
b=input('나이:')
print(a,'님 안녕하세요?')
print(20-int(b),'년 후면 20살이시네요!')
# Out:
# 이름:신승우
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2870/4008109285.py in <cell line: 0>()
#       1 a=input('이름:')
# ----> 2 b=input('나이:')
#       3 print(a,'님 안녕하세요?')
#       4 print(20-int(b),'년 후면 20살이시네요!')
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
print(7/3)
print(7//3)
print(7%3)
# Out:
# 2.3333333333333335
# 2
# 1

# %%
sec=int(input('시간을 초 단위로 입력하세요:'))
minutes=sec//60
seconds=sec//60
print(f'{minutes}분{seconds}초')
# Out:
# 시간을 초 단위로 입력하세요:1
# 0분0초

# %%
print('#######################################################################')

print('[한양양과학학기술고등학교 학생증]')

a=input('학번:')
# Out:
# #######################################################################
# [한양양과학학기술고등학교 학생증]
# 학번:10812
